# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
aktivise = plt.imread('Assets/aktivis.jpg')
plt.imshow(aktivise)
print(aktivise.shape)
# Out:
# (1294, 2722, 3)

# %%
Badeni=aktivise[0:1200, 0:460]
plt.imshow(Badeni)
print(Badeni.shape)
plt.axis('off')
# Out:
# (1200, 460, 3)
# (np.float64(-0.5), np.float64(459.5), np.float64(1199.5), np.float64(-0.5))

# %%
Albert=aktivise[0:1200, 460:910]
plt.imshow(Albert)
print(Albert.shape)
plt.axis('off')
# Out:
# (1200, 450, 3)
# (np.float64(-0.5), np.float64(449.5), np.float64(1199.5), np.float64(-0.5))

# %%
rafal=aktivise[0:1200, 910:1360]
plt.imshow(rafal)
print(rafal.shape)
plt.axis('off')
# Out:
# (1200, 450, 3)
# (np.float64(-0.5), np.float64(449.5), np.float64(1199.5), np.float64(-0.5))

# %%
Jolenta=aktivise[0:1200, 1360:1815]
plt.imshow(Jolenta)
print(Jolenta.shape)
plt.axis('off')
# Out:
# (1200, 455, 3)
# (np.float64(-0.5), np.float64(454.5), np.float64(1199.5), np.float64(-0.5))

# %%
Oczy=aktivise[0:1200, 1815:2270]
plt.imshow(Oczy)
print(Oczy.shape)
plt.axis('off')
# Out:
# (1200, 455, 3)
# (np.float64(-0.5), np.float64(454.5), np.float64(1199.5), np.float64(-0.5))

# %%
Draka=aktivise[0:1200, 2270:2760]
plt.imshow(Draka)
print(Draka.shape)
plt.axis('off')
# Out:
# (1200, 452, 3)
# (np.float64(-0.5), np.float64(451.5), np.float64(1199.5), np.float64(-0.5))

# %%
Badeni=aktivise[0:1200, 0:460]
plt.imshow(Badeni)
print(Badeni.shape)
plt.axis('off')

Albert=aktivise[0:1200, 460:910]
plt.imshow(Albert)
print(Albert.shape)
plt.axis('off')

rafal=aktivise[0:1200, 910:1360]
plt.imshow(rafal)
print(rafal.shape)
plt.axis('off')

Jolenta=aktivise[0:1200, 1360:1815]
plt.imshow(Jolenta)
print(Jolenta.shape)
plt.axis('off')

Oczy=aktivise[0:1200, 1815:2270]
plt.imshow(Oczy)
print(Oczy.shape)
plt.axis('off')

Draka=aktivise[0:1200, 2270:2760]
plt.imshow(Draka)
print(Draka.shape)
plt.axis('off')

plt.axis('on')
plt.show()
# Out:
# (1200, 460, 3)
# (1200, 450, 3)
# (1200, 450, 3)
# (1200, 455, 3)
# (1200, 455, 3)
# (1200, 452, 3)
